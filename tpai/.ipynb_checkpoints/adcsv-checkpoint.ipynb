# %%
# 每行描述一条广告素材，各字段之间由逗号分隔，顺序依次为“creativeID，adID，camgaignID，advertiserID，appID，appPlatform”。
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import pandas as pd

path = '~/codedata/tpai/pre/'
trainfile = 'train.csv'
train = pd.read_csv(path + trainfile)
ad = pd.read_csv(path + 'ad.csv')

# %%
train = pd.merge(train, ad, on='creativeID', how='left')
train.head()
# Out:
#    label  clickTime  conversionTime  creativeID   userID  positionID  \
# 0      0     170000             NaN        3089  2798058         293
# 1      0     170000             NaN        1259   463234        6161
# 2      0     170000             NaN        4465  1857485        7434
# 3      0     170000             NaN        1004  2038823         977
# 4      0     170000             NaN        1887  2015141        3688
#
#    connectionType  telecomsOperator  adID  camgaignID  advertiserID  appID  \
# 0               1                 1  1321          83            10    434
# 1               1                 2  1535         685            80     14
# 2               4                 1   147         460             3    465
# 3               1                 1   411         564             3    465
# 4               1                 1   369         144            84    360
#
#    appPlatform
# 0            1
# 1            2
# 2            1
# 3            1
# 4            1

# %%
a = train['camgaignID'] == 357
a.any()
print train['creativeID'].max()
# Out:
# False

# %%
test = {}
def property(var, train):
    # 点击量的统计直方图     
    sns.distplot(train[var], kde=False)
    fig = plt.figure()
    count = train[var].value_counts()
    count_index = count.values < 5
    if count_index.any():
        train[var].replace(count[count_index].index, 10000, inplace=True)
    means = train.groupby(var)['label'].mean()
    # 根据var属性的每一个取值做均值     
    plt.scatter(x=means.index, y = means.values)
    sort_means = means.sort_values(ascending = False)
    fig = plt.figure()
    # 按顺序画散点图
    plt.scatter(x = range(0,len(sort_means)), y = sort_means.values)
    return (var, len(train[var].value_counts()), means.max() - means.min(), means.std())

# %%
# 存在安卓、苹果、未知
var = 'appPlatform'
test[var] = property(var, train)

# %%
# 广告的appID
var = 'appID'
test[var] = property(var, train)

# %%
var = 'advertiserID'
test[var] = property(var, train)

# %%
# camgaignID
var = 'camgaignID'
test[var] = property(var, train)

# %%
# var = 'camgaignID'
# 把出现次数少于一定数目的统一编码
# print train[var].value_counts()
# count = train[var].value_counts(sort=True, ascending=False)
# tmp1 = count.values < 200
# train[var].replace(count[tmp1].index, 808, inplace = True)
# type(count)

# dfTrain = train
# # var = 'campaignID'
# means = dfTrain.groupby(var)['label'].mean()
# tmp1 = means.values > 0.6
# dfTrain[var].replace(means[tmp1].index, -1, inplace = True)
# tmp1 = means.values < 0.601
# tmp2 = means.values > 0.399
# dfTrain[var].replace(means[tmp1 & tmp2].index, -2, inplace = True)
# tmp1 = means.values < 0.3991
# tmp2 = means.values > 0.35
# dfTrain[var].replace(means[tmp1 & tmp2].index, -3, inplace = True)
# tmp1 = means.values < 0.351
# tmp2 = means.values > 0.299
# dfTrain[var].replace(means[tmp1 & tmp2].index, -4, inplace = True)
# tmp1 = means.values < 0.2991
# tmp2 = means.values > 0.20
# dfTrain[var].replace(means[tmp1 & tmp2].index, -5, inplace = True) 
# tmp1 = means.values < 0.201
# tmp2 = means.values > 0.18
# dfTrain[var].replace(means[tmp1 & tmp2].index, -6, inplace = True) 
# tmp1 = means.values < 0.181
# tmp2 = means.values > 0.16
# dfTrain[var].replace(means[tmp1 & tmp2].index, -7, inplace = True) 
# tmp1 = means.values < 0.161
# tmp2 = means.values > 0.14
# dfTrain[var].replace(means[tmp1 & tmp2].index, -8, inplace = True) 
# tmp1 = means.values < 0.141
# tmp2 = means.values > 0.12
# dfTrain[var].replace(means[tmp1 & tmp2].index, -9, inplace = True) 
# tmp1 = means.values < 0.121
# tmp2 = means.values > 0.10
# dfTrain[var].replace(means[tmp1 & tmp2].index, -10, inplace = True) 
# tmp1 = means.values < 0.101
# tmp2 = means.values > 0.08
# dfTrain[var].replace(means[tmp1 & tmp2].index, -11, inplace = True) 
# tmp1 = means.values < 0.081
# tmp2 = means.values > 0.06
# dfTrain[var].replace(means[tmp1 & tmp2].index, -12, inplace = True) 
# tmp1 = means.values < 0.061
# tmp2 = means.values > 0.04
# dfTrain[var].replace(means[tmp1 & tmp2].index, -13, inplace = True) 
# tmp1 = means.values < 0.041
# tmp2 = means.values > 0.02
# dfTrain[var].replace(means[tmp1 & tmp2].index, -14, inplace = True) 
# tmp1 = means.values < 0.201
# dfTrain[var].replace(means[tmp1].index, -15, inplace = True)

# %%
var = 'adID' 
test[var] = property(var, train)

# %%
for (k,v) in test.items():
    print v
# Out:
# ('advertiserID', 89, 0.42384105960264901, 0.05492409862736055)
# ('adID', 3060, 0.63636363636363635, 0.041196377249297429)
# ('appID', 50, 0.42384105960264901, 0.06958037043067912)
# ('camgaignID', 635, 0.63636363636363635, 0.049115659693790684)
# ('appPlatform', 2, 0.0012702159343590154, 0.0008981783007564663)

# %%
feats = ['label', 'adID', 'camgaignID','advertiserID','appID','appPlatform']
corr = train[feats].corr()
fig = plt.figure(figsize=(12,10))
sns.heatmap(corr, vmax=.8, square=True)
corr
# Out:
#                  label      adID  camgaignID  advertiserID     appID  \
# label         1.000000  0.013469   -0.004097      0.036255 -0.000401
# adID          0.013469  1.000000    0.306669     -0.047524  0.014941
# camgaignID   -0.004097  0.306669    1.000000     -0.206144  0.170046
# advertiserID  0.036255 -0.047524   -0.206144      1.000000 -0.660020
# appID        -0.000401  0.014941    0.170046     -0.660020  1.000000
# appPlatform   0.003367  0.014622   -0.127639      0.433173 -0.897595
#
#               appPlatform
# label            0.003367
# adID             0.014622
# camgaignID      -0.127639
# advertiserID     0.433173
# appID           -0.897595
# appPlatform      1.000000
