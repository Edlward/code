# %%
# --coding:utf-8--

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
path = '~/code/tpai/'
submission = pd.read_csv(path + 'submissionx.csv')

# 输出两种预测结果的平均值
var1 = 'instanceID'
print submission.groupby(var1)['proba'].mean()
# Out:
# instanceID
# 0    0.025451
# 1    0.025532
# Name: proba, dtype: float64

# %%
sns.distplot(submission[var1],kde=False)
submission.head()
# Out:
#    instanceID     proba
# 0           0  0.025349
# 1           0  0.025349
# 2           0  0.025349
# 3           0  0.025349
# 4           0  0.025349

# %%
sns.distplot(submission[var1], kde=False)
num = submission[var1].value_counts()
print num
# Out:
# 0    564949
# 1     14846
# Name: instanceID, dtype: int64

# %%
# sns.distplot(submission[submission['testlabel']]['proba'])
fig = plt.figure(figsize = (16, 5))
sns.distplot(submission[submission[var1] == 1]['proba'], kde=False)

# %%
fig = plt.figure(figsize = (16, 5))
plt.xlim(0,0.35)
plt.ylim(0,4000)
sns.distplot((submission[submission[var1] == 0])['proba'], kde=False)
